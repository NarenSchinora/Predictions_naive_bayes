# %%
import numpy as np
import pandas as pd

# %%
z = pd.read_csv("trainset.csv")
p = pd.read_csv("trainlabels.csv")

# %%
p.drop(['respondent_id'], axis=1,inplace=True)
p
# Out:
#        xyz_vaccine  seasonal_vaccine
# 0                0                 0
# 1                0                 1
# 2                0                 0
# 3                0                 1
# 4                0                 0
# ...            ...               ...
# 26702            0                 0
# 26703            0                 0
# 26704            0                 1
# 26705            0                 0
# 26706            0                 0
#
# [26707 rows x 2 columns]

# %%
re = pd.concat([z, p], axis=1, join='inner')

# %%
re
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
re.drop(['employment_occupation', 'employment_industry'], axis=1,inplace=True)
re.drop(['hhs_geo_region'], axis=1,inplace=True)

# %%
re.drop(['health_insurance'], axis=1,inplace=True)

# %%
d = pd.read_csv("trainset.csv")

# %%
for col in re:
    s = re[col].isnull().sum()
    print(f"{col}:{s}")
count = 0
# Out:
# respondent_id:0
# xyz_concern:79
# xyz_knowledge:109
# behavioral_antiviral_meds:67
# behavioral_avoidance:195
# behavioral_face_mask:16
# behavioral_wash_hands:35
# behavioral_large_gatherings:80
# behavioral_outside_home:77
# behavioral_touch_face:119
# doctor_recc_xyz:1965
# doctor_recc_seasonal:1965
# chronic_med_condition:245
# child_under_6_months:58
# health_worker:54
# opinion_xyz_vacc_effective:89
# opinion_xyz_risk:42
# opinion_xyz_sick_from_vacc:13
# opinion_seas_vacc_effective:40
# opinion_seas_risk:32
# opinion_seas_sick_from_vacc:10
# age_group:0
# education:639
# race:0
# sex:0
# income_poverty:3650
# marital_status:639
# rent_or_own:1270
# employment_status:692
# census_msa:0
# household_adults:23
# household_children:23
# xyz_vaccine:0
# seasonal_vaccine:0

# %%
for i in range(len(re.index)): 
    if re.iloc[i].isnull().sum()>=8:
        print(f"{i}: {re.iloc[i].isnull().sum()}")
        indexAge = re[(re['respondent_id'] == re.iloc[i].respondent_id)].index
        re.drop(indexAge, inplace=True)

# %%
count = 0
for i in range(len(re.index)): 
    if re.iloc[i].isnull().sum()>=8:
        count+=1
        print(f"{i}: {re.iloc[i].isnull().sum()}")
print(count)
# Out:
# 0

# %%
print(" \nCount total NaN in a DataFrame : \n\n", 
       re.isnull().sum().sum())
# Out:
#
# Count total NaN in a DataFrame :
#
#  12226

# %%
re1 = re.interpolate()

# %%
for col in re1:
    s = re1[col].isnull().sum()
    print(f"{col}:{s}")
count = 0
# Out:
# respondent_id:0
# xyz_concern:0
# xyz_knowledge:0
# behavioral_antiviral_meds:0
# behavioral_avoidance:0
# behavioral_face_mask:0
# behavioral_wash_hands:0
# behavioral_large_gatherings:0
# behavioral_outside_home:0
# behavioral_touch_face:0
# doctor_recc_xyz:0
# doctor_recc_seasonal:0
# chronic_med_condition:0
# child_under_6_months:0
# health_worker:0
# opinion_xyz_vacc_effective:0
# opinion_xyz_risk:0
# opinion_xyz_sick_from_vacc:0
# opinion_seas_vacc_effective:0
# opinion_seas_risk:0
# opinion_seas_sick_from_vacc:0
# age_group:0
# education:0
# race:0
# sex:0
# income_poverty:0
# marital_status:0
# rent_or_own:0
# employment_status:0
# census_msa:0
# household_adults:0
# household_children:0
# xyz_vaccine:0
# seasonal_vaccine:0

# %%
re1["education"].fillna(re1["education"].mode()[0], inplace = True) 
re1["employment_status"].fillna(re1["employment_status"].mode()[0], inplace = True) 
re1["marital_status"].fillna(re1["marital_status"].mode()[0], inplace = True) 
re1["income_poverty"].fillna(re1["income_poverty"].mode()[0], inplace = True) 
re1["rent_or_own"].fillna(re1["rent_or_own"].mode()[0], inplace = True)

# %%
re1.shape
from sklearn.model_selection import train_test_split

# %%
x = re1.drop(['xyz_vaccine', 'seasonal_vaccine','respondent_id'], axis=1)
y1 = re1['xyz_vaccine']
y2 =  re1['seasonal_vaccine']
resid = re1['respondent_id']

# %%
x_train, y_train = x,y2
x_test = fin_x

# %%
categorical = [col for col in x_train.columns if x_train[col].dtypes == 'O']

categorical
# Out:
# ['age_group',
#  'education',
#  'race',
#  'sex',
#  'income_poverty',
#  'marital_status',
#  'rent_or_own',
#  'employment_status',
#  'census_msa']

# %%
numerical = [col for col in x_train.columns if x_train[col].dtypes != 'O']

numerical
# Out:
# ['xyz_concern',
#  'xyz_knowledge',
#  'behavioral_antiviral_meds',
#  'behavioral_avoidance',
#  'behavioral_face_mask',
#  'behavioral_wash_hands',
#  'behavioral_large_gatherings',
#  'behavioral_outside_home',
#  'behavioral_touch_face',
#  'doctor_recc_xyz',
#  'doctor_recc_seasonal',
#  'chronic_med_condition',
#  'child_under_6_months',
#  'health_worker',
#  'opinion_xyz_vacc_effective',
#  'opinion_xyz_risk',
#  'opinion_xyz_sick_from_vacc',
#  'opinion_seas_vacc_effective',
#  'opinion_seas_risk',
#  'opinion_seas_sick_from_vacc',
#  'household_adults',
#  'household_children']

# %%
import category_encoders as ce
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score

# %%
enc = ce.OneHotEncoder(cols=['age_group',
 'education',
 'race',
 'sex',
 'income_poverty',
 'marital_status',
 'rent_or_own',
 'employment_status',
 'census_msa'])

x_train = enc.fit_transform(x_train)

x_test = enc.transform(x_test)

# %%
x_train.head()
# Out:
#        xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 11944          1.0            2.0                        0.0
# 15883          0.0            1.0                        0.0
# 12661          1.5            1.5                        0.0
# 2196           2.0            1.0                        0.0
# 19029          3.0            2.0                        0.0
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 11944                   1.0                   1.0                    1.0
# 15883                   0.0                   0.0                    0.0
# 12661                   0.0                   0.0                    0.0
# 2196                    0.0                   0.0                    1.0
# 19029                   0.0                   0.0                    1.0
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# 11944                          0.0                      0.0
# ...

# %%
cols = x_train.columns

# %%
sc = RobustScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train = pd.DataFrame(x_train, columns=[cols])

# %%
x_test = pd.DataFrame(x_test, columns=[cols])

# %%
x_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [219], line 1
# ----> 1 x_train.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
gn = GaussianNB()
gn.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
p_pred = gn.predict_proba(x_test)

# %%
u_pred = p_pred[:,1]
u_pred
# Out:
# array([4.81200863e-04, 3.03060341e-06, 9.98835487e-01, ...,
#        2.40840202e-04, 8.72485911e-01, 7.26514562e-01])

# %%
z_pred = y_pred[:,1]
z_pred
# Out:
# array([1.51743218e-02, 3.06124003e-05, 9.94151453e-01, ...,
#        4.38885120e-04, 1.05220263e-01, 3.88537133e-01])

# %%
z_pred
# Out:
# array([1.51743218e-02, 3.06124003e-05, 9.94151453e-01, ...,
#        4.38885120e-04, 1.05220263e-01, 3.88537133e-01])

# %%
o = pd.DataFrame(z_pred)
l = pd.DataFrame(u_pred)
fle = pd.concat([final_resid,o,l], axis=1, join='inner')

# %%
finale
# Out:
#        respondent_id         0         0
# 0              26707  0.015174  0.000481
# 1              26708  0.000031  0.000003
# 2              26709  0.994151  0.998835
# 3              26710  0.391166  0.999161
# 4              26711  0.819053  0.549482
# ...              ...       ...       ...
# 26703          53410  0.670763  0.944533
# 26704          53411  0.152728  0.012134
# 26705          53412  0.000439  0.000241
# 26706          53413  0.105220  0.872486
# 26707          53414  0.388537  0.726515
#
# [26708 rows x 3 columns]

# %%
print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.7500

# %%
we = pd.read_csv("testset.csv")

# %%
we.drop(['employment_occupation', 'employment_industry'], axis=1,inplace=True)
we.drop(['hhs_geo_region'], axis=1,inplace=True)
we.drop(['health_insurance'], axis=1,inplace=True)

# %%
we.shape
# Out:
# (26708, 32)

# %%
for col in we:
    s = we[col].isnull().sum()
    print(f"{col}:{s}")
count = 0
# Out:
# respondent_id:0
# xyz_concern:85
# xyz_knowledge:122
# behavioral_antiviral_meds:79
# behavioral_avoidance:213
# behavioral_face_mask:19
# behavioral_wash_hands:40
# behavioral_large_gatherings:72
# behavioral_outside_home:82
# behavioral_touch_face:128
# doctor_recc_xyz:2160
# doctor_recc_seasonal:2160
# chronic_med_condition:932
# child_under_6_months:813
# health_worker:789
# opinion_xyz_vacc_effective:398
# opinion_xyz_risk:380
# opinion_xyz_sick_from_vacc:375
# opinion_seas_vacc_effective:452
# opinion_seas_risk:499
# opinion_seas_sick_from_vacc:521
# age_group:0
# education:1407
# race:0
# sex:0
# income_poverty:4497
# marital_status:1442
# rent_or_own:2036
# employment_status:1471
# census_msa:0
# household_adults:225
# household_children:225

# %%
we1 = we.interpolate()

# %%
for col in we1:
    s = we1[col].isnull().sum()
    print(f"{col}:{s}")
count = 0
# Out:
# respondent_id:0
# xyz_concern:0
# xyz_knowledge:0
# behavioral_antiviral_meds:0
# behavioral_avoidance:0
# behavioral_face_mask:0
# behavioral_wash_hands:0
# behavioral_large_gatherings:0
# behavioral_outside_home:0
# behavioral_touch_face:0
# doctor_recc_xyz:0
# doctor_recc_seasonal:0
# chronic_med_condition:0
# child_under_6_months:0
# health_worker:0
# opinion_xyz_vacc_effective:0
# opinion_xyz_risk:0
# opinion_xyz_sick_from_vacc:0
# opinion_seas_vacc_effective:0
# opinion_seas_risk:0
# opinion_seas_sick_from_vacc:0
# age_group:0
# education:1407
# race:0
# sex:0
# income_poverty:4497
# marital_status:1442
# rent_or_own:2036
# employment_status:1471
# census_msa:0
# household_adults:0
# household_children:0

# %%
we1["education"].fillna(we1["education"].mode()[0], inplace = True) 
we1["employment_status"].fillna(we1["employment_status"].mode()[0], inplace = True) 
we1["marital_status"].fillna(we1["marital_status"].mode()[0], inplace = True) 
we1["income_poverty"].fillna(we1["income_poverty"].mode()[0], inplace = True) 
we1["rent_or_own"].fillna(we1["rent_or_own"].mode()[0], inplace = True)

# %%
fin_x = we1.drop(['respondent_id'], axis=1)
final_resid = we1['respondent_id']

# %%
fin_x.shape
# Out:
# (26708, 31)

# %%
finale.columns = ['respondent_id','xyz_vaccine', 'seasonal_vaccine']

# %%
finale.to_csv("submission_1.csv",index=False)
